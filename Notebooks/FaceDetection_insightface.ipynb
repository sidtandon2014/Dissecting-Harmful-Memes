# %%
import cv2
import numpy as np
import insightface
from insightface.app import FaceAnalysis
from insightface.data import get_image as ins_get_image

app = FaceAnalysis(providers=['CUDAExecutionProvider', 'CPUExecutionProvider'])
app.prepare(ctx_id=0, det_size=(640, 640))
img = ins_get_image('../Datasets/constraint22_dataset_uspolitics/covid_memes_2.png')
faces = app.get(img)
rimg = app.draw_on(img, faces)
cv2.imwrite("./t1_output.jpg", rimg)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xf but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.multiarray failed to import
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in function __import__> returned a result with an error set
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15208/1288520017.py in <module>
#       1 import cv2
#       2 import numpy as np
# ----> 3 import insightface
#       4 from insightface.app import FaceAnalysis
#       5 from insightface.data import get_image as ins_get_image
#
# ~\Anaconda3\envs\py39\lib\site-packages\insightface\__init__.py in <module>
#      16 from . import model_zoo
#      17 from . import utils
# ---> 18 from . import app
#      19 from . import data
#      20 from . import thirdparty
#
# ~\Anaconda3\envs\py39\lib\site-packages\insightface\app\__init__.py in <module>
#       1 from .face_analysis import *
# ----> 2 from .mask_renderer import *
#
# ~\Anaconda3\envs\py39\lib\site-packages\insightface\app\mask_renderer.py in <module>
#       6 from .face_analysis import FaceAnalysis
#       7 from ..utils import get_model_dir
# ----> 8 from ..thirdparty import face3d
#       9 from ..data import get_image as ins_get_image
#      10 from ..utils import DEFAULT_MP_NAME
#
# ~\Anaconda3\envs\py39\lib\site-packages\insightface\thirdparty\face3d\__init__.py in <module>
#       1 #import mesh
#       2 #import morphable_model
# ----> 3 from . import mesh
#       4 from . import morphable_model
#
# ~\Anaconda3\envs\py39\lib\site-packages\insightface\thirdparty\face3d\mesh\__init__.py in <module>
#       8
#       9 from .cython import mesh_core_cython
# ---> 10 from . import io
#      11 from . import vis
#      12 from . import transform
#
# ~\Anaconda3\envs\py39\lib\site-packages\insightface\thirdparty\face3d\mesh\io.py in <module>
#       5 import numpy as np
#       6 import os
# ----> 7 from skimage import io
#       8 from time import time
#       9
#
# ~\Anaconda3\envs\py39\lib\importlib\_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# ~\Anaconda3\envs\py39\lib\site-packages\skimage\_shared\lazy.py in __getattr__(name)
#      60     def __getattr__(name):
#      61         if name in submodules:
# ---> 62             return importlib.import_module(f'{package_name}.{name}')
#      63         elif name in attr_to_modules:
#      64             submod = importlib.import_module(
#
# ~\Anaconda3\envs\py39\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\Anaconda3\envs\py39\lib\site-packages\skimage\io\__init__.py in <module>
#      13
#      14
# ---> 15 reset_plugins()
#      16
#      17 WRAP_LEN = 73
#
# ~\Anaconda3\envs\py39\lib\site-packages\skimage\io\manage_plugins.py in reset_plugins()
#      85 def reset_plugins():
#      86     _clear_plugins()
# ---> 87     _load_preferred_plugins()
#      88
#      89
#
# ~\Anaconda3\envs\py39\lib\site-packages\skimage\io\manage_plugins.py in _load_preferred_plugins()
#      65                 'imread']
#      66     for p_type in io_types:
# ---> 67         _set_plugin(p_type, preferred_plugins['all'])
#      68
#      69     plugin_types = (p for p in preferred_plugins.keys() if p != 'all')
#
# ~\Anaconda3\envs\py39\lib\site-packages\skimage\io\manage_plugins.py in _set_plugin(plugin_type, plugin_list)
#      77             continue
#      78         try:
# ---> 79             use_plugin(plugin, kind=plugin_type)
#      80             break
#      81         except (ImportError, RuntimeError, OSError):
#
# ~\Anaconda3\envs\py39\lib\site-packages\skimage\io\manage_plugins.py in use_plugin(name, kind)
#     248             kind = [kind]
#     249
# --> 250     _load(name)
#     251
#     252     for k in kind:
#
# ~\Anaconda3\envs\py39\lib\site-packages\skimage\io\manage_plugins.py in _load(plugin)
#     291     else:
#     292         modname = plugin_module_name[plugin]
# --> 293         plugin_module = __import__('skimage.io._plugins.' + modname,
#     294                                    fromlist=[modname])
#     295
#
# ~\Anaconda3\envs\py39\lib\site-packages\skimage\io\_plugins\imageio_plugin.py in <module>
#       3 from functools import wraps
#       4 import numpy as np
# ----> 5 from imageio import imread as imageio_imread, imsave
#       6
#       7
#
# ~\Anaconda3\envs\py39\lib\site-packages\imageio\__init__.py in <module>
#      20
#      21 # Load some bits from core
# ---> 22 from .core import FormatManager, RETURN_BYTES
#      23
#      24 # Instantiate the old format manager
#
# ~\Anaconda3\envs\py39\lib\site-packages\imageio\core\__init__.py in <module>
#      14 from .fetching import get_remote_file, InternetNotAllowedError, NeedDownloadError
#      15 from .request import Request, read_n_bytes, RETURN_BYTES
# ---> 16 from .format import Format, FormatManager
#
# ~\Anaconda3\envs\py39\lib\site-packages\imageio\core\format.py in <module>
#      38 from . import Array, asarray
#      39 from .request import ImageMode, Request
# ---> 40 from ..config import known_plugins, known_extensions, PluginConfig, FileExtension
#      41 from ..config.plugins import _original_order
#      42 from .imopen import imopen, _get_config
#
# ~\Anaconda3\envs\py39\lib\site-packages\imageio\config\__init__.py in <module>
#       5     video_extensions,
#       6 )
# ----> 7 from .plugins import known_plugins, PluginConfig
#       8
#       9 __all__ = [
#
# ~\Anaconda3\envs\py39\lib\site-packages\imageio\config\plugins.py in <module>
#       2 import importlib
#       3
# ----> 4 from ..core.legacy_plugin_wrapper import LegacyPlugin
#       5
#       6
#
# ~\Anaconda3\envs\py39\lib\site-packages\imageio\core\legacy_plugin_wrapper.py in <module>
#       4
#       5 from .request import IOMode, Request, InitializationError
# ----> 6 from .v3_plugin_api import PluginV3, ImageProperties
#       7
#       8
#
# ~\Anaconda3\envs\py39\lib\site-packages\imageio\core\v3_plugin_api.py in <module>
#       1 from . import Request
# ----> 2 from numpy.typing import ArrayLike
#       3 import numpy as np
#       4 from typing import Optional, Dict, Any, Tuple, Union, List
#       5 from dataclasses import dataclass
#
# ~\Anaconda3\envs\py39\lib\site-packages\numpy\typing\__init__.py in <module>
#     322 )
#     323 from ._shape import _Shape, _ShapeLike
# --> 324 from ._dtype_like import (
#     325     DTypeLike as DTypeLike,
#     326     _SupportsDType,
#
# ~\Anaconda3\envs\py39\lib\site-packages\numpy\typing\_dtype_like.py in <module>
#      14
#      15 from ._shape import _ShapeLike
# ---> 16 from ._generic_alias import _DType as DType
#      17
#      18 from ._char_codes import (
#
# ~\Anaconda3\envs\py39\lib\site-packages\numpy\typing\_generic_alias.py in <module>
#     209
#     210 if TYPE_CHECKING or sys.version_info >= (3, 9):
# --> 211     _DType = np.dtype[ScalarType]
#     212     NDArray = np.ndarray[Any, np.dtype[ScalarType]]
#     213 else:
#
# TypeError: 'numpy._DTypeMeta' object is not subscriptable
